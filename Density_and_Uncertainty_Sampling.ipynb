# %% [markdown]
# <a href="https://colab.research.google.com/github/Roho1999/Bachelor_Thesis/blob/main/Density_and_Uncertainty_Sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cleaning the data

# %%
"""
Created on Thu Sep 16 16:18:51 2021
@author: Robin Feldmann
"""
import re
import string
import numpy as np
from collections import Counter
from tensorflow.keras.preprocessing.text import Tokenizer
import matplotlib.pyplot as plt
# %load_ext tensorboard

#Simpliefies the Data to 3 labels Positive, Negative and Neutral
def convert_Sentiment(sentiment):
    if sentiment == "Extremely Positive":
        return 2
    elif sentiment == "Extremely Negative":
        return 0
    elif sentiment == "Positive":
        return 2
    elif sentiment == "Negative":
        return 0
    else:
        return 1

#removes all URLs 
def remove_URL(text):
    url = re.compile(r"https?://\S+|www\.\S+")
    return url.sub(r"", text)

#removes hashtags
def remove_hashtags(text):
   
    text =  re.sub(r"#\w+", " ", text)
    return text

#deletes all numbers
#this doesn't increases performance and results, so it isn't used
def remove_numbers(text):
    text = re.sub(r"\d+", " ", text)
    return text

#removes words with 2 or less letters
#this doesn't increases performance and results, so it isn't used
def remove_short_words(text):
    
    text = re.sub(r'\b\w{1,2}\b', " ", text)
    
    return text


#removes all mentions in form of @name
#names are not important for the sentiment and bad for tokenization and
#embedding
#led to a relatively strong increase in performance
def remove_mentions(text):
    text = re.sub(r"@([a-zA-Z0-9_.-]{1,100})", " ", text)
    return text

#removes contractions
#this doesn't increases performance and results, so it isn't used
def decontraction(text):
    text = re.sub(r"won\'t", " will not", text)
    text = re.sub(r"won\'t've", " will not have", text)
    text = re.sub(r"can\'t", " can not", text)
    text = re.sub(r"don\'t", " do not", text)
    
    text = re.sub(r"can\'t've", " can not have", text)
    text = re.sub(r"ma\'am", " madam", text)
    text = re.sub(r"let\'s", " let us", text)
    text = re.sub(r"ain\'t", " am not", text)
    text = re.sub(r"shan\'t", " shall not", text)
    text = re.sub(r"sha\n't", " shall not", text)
    text = re.sub(r"o\'clock", " of the clock", text)
    text = re.sub(r"y\'all", " you all", text)
    
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"n\'t've", " not have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'d've", " would have", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ll've", " will have", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    text = re.sub(r"\'re", " are", text)
    return text   



def remove_punct(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords


stop = set(stopwords.words("english"))
#remove all stopwords from text and seperate every lowers words with space
def remove_stopwords(text):
    
    filtered_words = [word.lower() for word in text.split() if word.lower() not in stop]
    
    return " ".join(filtered_words)



#takes chars that are more then doubled and presents them as double chars
#Example "Helllllo" --> "Hello"
#helps to identify identical words with misspellings
def repeated_char(text):
    rchar = text.group(0) 
    
    if len(rchar) > 1:
        return rchar[0:2] 

#helper function for repeated_char
def unique_char(rep, text):
    substitute = re.sub(r'(\w)\1+', rep, text)
    return substitute



#returns text as lower case
def to_lower(text):
    
    return text.lower()


#removes articles from data, leads to less complex data and no hit in accuracy
def remove_articles(text):


  articles = {'a': '', 'an':'', 'and':'', 'the':''}
  rest = []
  for word in text.split():
    if word not in articles:
      rest.append(word)
  return ' '.join(rest)

#counts how often a word is used and determines the number of unique words
def count_words(text_col):
   
    
    count = Counter()
    for text in text_col.values:
        for word in text.split():
            count[word] += 1
    number_unique_words = len(count)
    return count, number_unique_words




#tokenize the words 
def tokenize(train_sentences, val_sentences, num_unique_words):
   

    #vectorize a text corpus by turning each text into a sequence of integers
    tokenizer = Tokenizer(num_words=num_unique_words)
    
    tokenizer.fit_on_texts(np.append(train_sentences, val_sentences))
    
    word_index = tokenizer.word_index
    return tokenizer, word_index

#shows a simple barplot of given data 
def simple_barplot(data,names="",color=['green','red', 'black', 'blue', 'violet'],
                   title="", labelx="", labely=""):
    
    f = plt.figure()
    plt.bar(x = data, height = names, color=color)
    f.set_figwidth(10)
    plt.title(title, fontweight="heavy")
    plt.ylabel(labely, fontweight="heavy")
    plt.xlabel(labelx, fontweight="heavy")
    plt.show()
    #f.savefig(f"barplot_{color[-1]}.png")
    #files.download(f"barplot_{color[-1]}.png")

#no hugh difference for the length to cut outliers: so not used
#maybe because tweets are inherently limited to a certain amount of letters
#sequences are just padded to the longest sequence
#twitter only allows for 280 characters
def show_length_distribution(train_sequences):
    
    #statistic of tweet length
    tweet_len=[len(item) for item in train_sequences]
    
    #important stats
    max_len = len(max(train_sequences, key=len))
    print(f"Length longest squence: {max_len}")
    quantile = np.quantile(tweet_len, 0.99)
    print(f"99% quantile: {quantile}")
    '''
    #plot
    dist = plt.figure()
    plt.scatter(np.arange(len(tweet_len))[::100], tweet_len[::100], color = "b")
    plt.axhline(quantile, color = "r")
    plt.title('Tweet-length')
    plt.ylabel('Length')
    plt.xlabel('Tweet-index')
    plt.legend(['99% Quantile', 'Tweets'], loc='upper right')
    plt.show()
    '''
    #dist.savefig("Length_distribution.png")
    #files.download("Length_distribution.png")
    #return int(quantile)
    return int(max_len)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## To use the code, download the train and test data from https://www.kaggle.com/datatattle/covid-19-nlp-text-classification and upload it to colab named corona_tweets_train.csv and corona_tweets_test.csv respectively

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report

"""
loading the corona tweets training and test data
from https://www.kaggle.com/datatattle/covid-19-nlp-text-classification

"""
df = pd.read_csv("corona_tweets_train.csv", encoding='latin1')
df_test = pd.read_csv("corona_tweets_test.csv", encoding='latin1')


#append the test data to the df to do the cleaning on both, after that split 
#split again
df = df.append(df_test)
#print(df.head())

#remove unnessessary colums 
df = df.drop(['Location','TweetAt','ScreenName'], axis=1)
 
#print(df.head())

"""
Process the target sentiments help:

"""

#show the distribution of sentiments
#simple_barplot(df.Sentiment.value_counts().index, df.Sentiment.value_counts().values,
#                   title="Original Data Distribution", labelx="Labels", labely="Samples") 

#simplify to positive,neutral and negative

df.Sentiment = df.Sentiment.apply(lambda x : convert_Sentiment(x))



#show new labels df.Sentiment.value_counts().index
#simple_barplot(["2 (Positive)","0 (Negative)","1 (Neutral)"], df.Sentiment.value_counts().values
#               ,title="Simplified Data Distribution", labelx="Labels", labely="Samples",
#               color = ["green", "red", "black"]) 




"""
Clean and preprocess the data, removing duplicates, punctation, URLs
and stopwords. Functions from utils.
"""
df = df.drop_duplicates()
print("\nOriginal Shape: ", df.shape, "\n")
print("No preprocessing:\n",df["OriginalTweet"].head(5))

#removes URLs, mentions, hashtags and short words in dataset   
df["OriginalTweet"] = df.OriginalTweet.map(remove_URL)

df["OriginalTweet"] = df.OriginalTweet.map(remove_mentions)

#does not increase accuracy or performance
#df["OriginalTweet"] = df.OriginalTweet.map(decontraction)

#increases accuracy and performance
df["OriginalTweet"] = df.OriginalTweet.map(remove_hashtags)


#removing short words does not lead to better accuracy
#df["OriginalTweet"] = df.OriginalTweet.map(remove_short_words)


#removing numbers does not changes accuracy by a lot but decreases runtime
df["OriginalTweet"] = df.OriginalTweet.map(remove_numbers)


#removes punctation dataset
df["OriginalTweet"] = df.OriginalTweet.map(remove_punct)


#removes stopwords dataset, and also removes multible consecutive spaces
#decreases complexity of the samples but also decreases accuracy significantly 
df["OriginalTweet"] = df.OriginalTweet.map(remove_stopwords)

#remove double words
df['OriginalTweet'] = df['OriginalTweet'].apply(lambda x : unique_char(repeated_char,x))

#all to lower case
df["OriginalTweet"] = df.OriginalTweet.map(to_lower)

df["OriginalTweet"] = df.OriginalTweet.map(remove_articles)



print("\nAfter prep.:\n ", df["OriginalTweet"].head(5))

#gets a list of word counts "counter" and the number of unique words
counter, num_unique_words = count_words(df.OriginalTweet)

print("\n", "The number of unique words in the OriginalTweet column: ", 
      num_unique_words, "\n")

'''

split dataset into original training and validation set 

'''


train_df = df[:41157]

val_df = df[41157:]

#split text and labels into numpy arrays
train_sentences = train_df.OriginalTweet.to_numpy()
train_labels = train_df.Sentiment.to_numpy()
val_sentences = val_df.OriginalTweet.to_numpy()
val_labels_np = val_df.Sentiment.to_numpy()


# Convert labels to categorical 
train_labels = to_categorical(train_labels, 3)
val_labels  = to_categorical(val_labels_np, 3)
print(f"The shape of the training and validation data: \n",
f"{train_sentences.shape} \n {val_sentences.shape} \n")
#create a tokenizer on the whole dataset and the respective word_index
tokenizer, word_index = tokenize(train_sentences, val_sentences, num_unique_words)

"""
tokenize the validation and trainings data 
"""
train_sequences = tokenizer.texts_to_sequences(train_sentences)
val_sequences = tokenizer.texts_to_sequences(val_sentences)
                                           
print(f"Sequence example: {train_sequences[0]}")

'''
show the distribution of the tweet-length and the maximal length
to find a good pad-size
'''

pad_size = show_length_distribution(train_sequences)


'''
pads the squences length of the longest tweet 
to simplify training
'''

train_padded = pad_sequences(train_sequences, maxlen = pad_size, 
                             padding="post", truncating="post")

val_padded = pad_sequences(val_sequences, maxlen = pad_size,
                             padding="post", truncating="post")
# Out:
# Original Shape:  (44955, 3)
#
# No preprocessing:
#  0    @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...
# 1    advice Talk to your neighbours family to excha...
# 2    Coronavirus Australia: Woolworths to give elde...
# 3    My food stock is not the only one which is emp...
# 4    Me, ready to go at supermarket during the #COV...
# Name: OriginalTweet, dtype: object
#
# After prep.:
#   0
# 1    advice talk neighbours family exchange phone n...
# 2    coronavirus australia woolworths give elderly ...
# 3    food stock one empty please dont panic enough ...
# 4    ready go supermarket outbreak im paranoid food...
# Name: OriginalTweet, dtype: object
#
#  The number of unique words in the OriginalTweet column:  40974
#
# The shape of the training and validation data:
#  (41157,)
#  (3798,)
#
# Sequence example: []
# Length longest squence: 41
# 99% quantile: 30.0

# %% [markdown]
# # The Model

# %%
'''
create LSTM model 
'''
name = "Bothreguse4_12_16"
from tensorflow.keras import layers, regularizers

#regularizers and constraints
l1 = regularizers.l1(1e-4)
constraint = tf.keras.constraints.max_norm(3.)


model = keras.models.Sequential()

model.add(layers.Embedding(num_unique_words, 512 , input_length = pad_size, name='embedding'))

#adding a convolutional layer didn't help the learning prozess, contrary to the paper 
#"Evaluation of Deep Learning Techniques in
#Sentiment Analysis from Twitter Data"

#breaks down the dimesionality of data and speeds up the learning significantly

#bidirectional because it is works well for language processing, since language is recursive by nature
#dropout to reduce overfitting on small details 
#regularizer to reduce exploding gradients
#
# with 512 dimensions best result but slower
model.add(layers.Bidirectional(
    layers.LSTM(512, return_sequences=True,
                recurrent_regularizer =l1,
                dropout =0.2,
                kernel_constraint= constraint,
                bias_constraint = constraint
                )))

#MaxPool worked better than global average pooling
model.add(layers.GlobalMaxPool1D())



model.add(layers.Dense(32, activation= "relu", 
                       bias_regularizer = l1))
                      # bias_constraint = constraint ))

model.add(layers.Dropout(0.2))



model.add(layers.Dense(3, activation= "softmax"))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 41, 512)           20978688
#
#  bidirectional (Bidirectiona  (None, 41, 1024)         4198400
#  l)
#
#  global_max_pooling1d (Globa  (None, 1024)             0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 32)                32800
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 25,209,987
# Trainable params: 25,209,987
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#creates a new model with the same architecture but new weights for experiment 
#with Uncertainty Sampling
model_entro = tf.keras.models.clone_model(model)


#compile the model
loss= keras.losses.CategoricalCrossentropy(from_logits = False)
#small learning rate to get a clear understanding of the learning curve and
#better comparability
optim = keras.optimizers.Adam(learning_rate=0.00006)
metrics = ["accuracy",tf.keras.metrics.Precision(),tf.keras.metrics.Recall()]
model_entro.compile(loss=loss, optimizer=optim, metrics=metrics)

# %% [markdown]
# # Different Implementations for calculating the entropy

# %% [markdown]
# The fastest implementation with simple numpy functions.
# this implementation (list_entropys3) is faster than the list_entropys1 function (with scpy.stats.entropy) by around 88.9006%:
#
# (100/0.0946) * 0.0105 - 100 = -88.9006 %

# %%
'''
fastest implementation with numpy log
gets the prediction of the model over the whole set of samples then computes
entropy

in a trial with 640 samples it took 6.734 seconds, 0.0105s per sample
'''
def list_entropys3(model, data):

  """ Computes entropy of label distribution. """
  entropys = []
  probs = model.predict(data)
  for i in range(0,len(probs)):
    entro = 0.
   
    prob = probs[i]
    # Compute entropy
   
    for j in prob:
      entro -= j * np.log(j)

    entropys.append(entro)
  
  
  return entropys

# %% [markdown]
# Two slower functions to compute the entropy for the whole dataset. For test details see below.

# %%
from scipy.stats import entropy
from numpy import e,log


#the two functions give back the list of the list of entropies of the training_pool in respect to
#the model


#slower implementation with scipy.stats.entropy 
#in a trial with 640 samples it took 60.56 seconds, 0.0946s per sample
def list_entropys(model, training_pool):
  entropys = []
 
  for i in range(0,len(training_pool)):
  
    entro = entropy(model.predict(training_pool[[i][:]]).reshape(3,))
    entropys.append(entro)
  return entropys

#faster implementation with numpy log
#in a trial with 640 samples it took 50.07 seconds, 0.0782s per sample
def list_entropys2(model, training_pool):

  """ Computes entropy of label distribution. """
  entropys = []
  for i in range(0,len(training_pool)):
    entro = 0.
   
    probs = model.predict(training_pool[[i][:]]).reshape(3,)
    # Compute entropy
   
    for i in probs:
      entro -= i * np.log(i)

    entropys.append(entro)

  return entropys

# %%
def normalize(array):
    max = np.max(array)
    min = np.min(array)

    return ((array - min) / (max - min))

# %%
from keras import backend as K
def vectorize(data, model):
  # with a Sequential model
  get_0rd_layer_output = K.function([model.layers[0].input],
                                    [model.layers[0].output])
  layer_output = [get_0rd_layer_output([x])[0] for x in data]

  return layer_output

# %%
from sklearn.neighbors import NearestNeighbors
def density(data, model):
  #transform data to matrices of word embeddings 
  word2vector = vectorize(data, model)  

  #represent text as the mean embedding
  np_vectorrep = np.array(word2vector)
  np_text2vector = np.mean(np_vectorrep, axis = 1)

 
  #computing the distance to the 3 nearest neighbors 
  #uses euklidean distance by default

  nbrs = NearestNeighbors(n_neighbors=3, algorithm='auto').fit(np_text2vector)
  distances, _ = nbrs.kneighbors(np_text2vector)


  #delete first column, because it is the distance to itself, hence 0
  reduced_distances = np.delete(distances, 0 , 1)

  #computes the arthmetric mean over the distances for each sample individually
  #this is the density
  densities= np.mean(reduced_distances, axis = 1)

  return densities

# %% [markdown]
# ## Testing execution speed

# %%
# '''
# Testing 1. implementation of entropy
# '''
# import copy
# training_pool = copy.deepcopy(train_padded)
# training_label = copy.deepcopy(train_labels)
# #select
# training_pool = training_pool[:,:] 
# training_label = training_label[:,:]

# import time
# start_time = time.time()
# entros = np.array(list_entropys(model_entro, training_pool))
# print("--- %s seconds ---" % (time.time() - start_time))

# #entros = np.array(list_entropys(model_entro, training_pool))
# print(entros)
# #print(training_pool)

# #sortes the training pool samples by their entropy value in descending order
# arr1inds = entros.argsort()
# sorted_arr1 = entros[arr1inds[::-1]]
# sorted_arr2 = training_pool[arr1inds[::-1]]

# print(sorted_arr1)
# print(sorted_arr2)

# %%
# '''
# Testing 2. implementation of entropy
# '''

# start_time = time.time()
# entros2 = np.array(list_entropys2(model_entro, training_pool))
# print("--- %s seconds ---" % (time.time() - start_time))


# #print(entros2)

# arr1inds = entros2.argsort()
# sorted_entropys = entros2[arr1inds[::-1]]
# sorted_samples = training_pool[arr1inds[::-1]]

# print(sorted_entropys)
# print(sorted_samples)

# %%
# '''
# Testing 3. implementation of entropy test: 
# '''

# start_time = time.time()
# entros3 = np.array(list_entropys3(model_entro, training_pool))
# print("--- %s seconds ---" % (time.time() - start_time))


# #print(entros2)

# arr1inds = entros3.argsort()
# sorted_entropys = entros3[arr1inds[::-1]]
# sorted_samples = training_pool[arr1inds[::-1]]

# print(sorted_entropys)
# print(sorted_samples)

# %% [markdown]
# ## Training the model

# %%
"""
train the model and return the accuracy and val_accuracy
"""

def train_model(model, train_padded, train_labels, val_padded, val_labels):

  import datetime
 
  # Clear any logs from previous runs
  # !rm -rf /logs/

  #clearing memory to avoid clutter from old runs
  tf.keras.backend.clear_session()
 
  ## Hyperparameters
  epochs = 30
  batchsize = 64
  early_stopping = keras.callbacks.EarlyStopping(monitor ="val_loss", 
                                          mode ="min", patience=3)

  #create the log file for tensorboard
  log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

  
  tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
 


  checkpoint_filepath = '/tmp/checkpoint'
  model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
  filepath=checkpoint_filepath,
  save_weights_only=True,
  monitor='val_accuracy',
  mode='max',
  save_best_only=True)
   
  #shuffels dataset before training so that the order isn't always the same and
  #model isn't bias towards the first samples more
  #then trains with given parameters
  history = model.fit(train_padded,
                      train_labels,
                      epochs=epochs,
                      batch_size = batchsize,
                      validation_data=(val_padded, val_labels),
                      callbacks=[early_stopping,tensorboard_callback,
                        model_checkpoint_callback],
                      verbose=1, shuffle=True)

  model.load_weights(checkpoint_filepath)

  return model, history.history['accuracy'][:], history.history['val_accuracy'][:]

# %% [markdown]
# # Main Training-Loop

# %%
#helper function to reset weights after each loop
weights = model_entro.get_weights()
reset_model = lambda model: model.set_weights(weights)

# %%
import copy

###HYPERPARAMETERS
#number of samples added per iteration
x= 2048
loops = 10
#number of iterations without improvement before stopping
patience = 10


#copy the padded training data and training labels for future use
training_pool = copy.deepcopy(train_padded)
training_label = copy.deepcopy(train_labels)
#select the maximal amount of training data 
training_pool = training_pool[:,:] 
training_label = training_label[:,:]



selected_samples = np.zeros( shape =(0,pad_size), dtype=np.int32)
selected_labels  = np.zeros( shape =(0,3), dtype=np.int32)

#take the first x random samples from the training pool and the labels to train
#the model 
#also delete the used samples from original training_pool and training_label



selected_samples = np.append(selected_samples, training_pool[:x][:], axis=0)
training_pool = np.delete(training_pool,slice(0,x) , axis=0)

selected_labels = np.append(selected_labels, training_label[:x][:], axis=0)
training_label = np.delete(training_label,slice(0,x) , axis=0)


'''
repeat loops times:
  train the model for one loop and calculate the entropy in respect to the trained
  model, select x new samples with highest entropy, reset model and relearn on the 
  new + old samples
'''



val_accuracies = []
train_accuracies = []
wait = 0
best = 1

for i in range(loops):

  print(f"\nIteration :{1+i} - Samples: {(i+1)*x} \n ")
  
  #clearing the old model graph and reset all the weights
  keras.backend.clear_session()
  reset_model(model_entro)
  
  
  model_entro, train_accuracy, val_accuracy = train_model(model_entro,
                                                          selected_samples,
                                                          selected_labels,
                                                          val_padded, val_labels)
  
  #save metrics for later
  max_index = np.argmax(val_accuracy)
  val_accuracies.append(val_accuracy[max_index])
  train_accuracies.append(train_accuracy[max_index])
  
  #get the density of the samples
  
  densities = density(training_pool, model_entro)
  #normalize the density to [0,1]
  densities = normalize(densities)
  

  #get the entropys and sort samples and labels in order of decending entropy
  entros = np.array(list_entropys3(model_entro, training_pool))

  #normalize and invert entropies (the higher the value the lower is the entropy)
  entros = 1-normalize(entros)

  #combine entropy and density to a combined score
  scores =  entros + densities 

  #sort the set into partitions with lowest x scores in the first x indices
  sorted_indices = np.argpartition(scores, x)

  sorted_scores = scores[sorted_indices]
  training_pool = training_pool[sorted_indices]
  training_label = training_label[sorted_indices]

  
  #add the x samples with the lowest scores values to the selected samples and
  #labels
  selected_samples = np.append(selected_samples, training_pool[:x][:], axis=0)
  selected_labels = np.append(selected_labels,  training_label[:x][:], axis=0)


  #delete the selected samples and labels from orginal pool 
  training_pool = training_pool[x:][:]
  training_label = training_label[x:][:]

  '''
  early stopping method that doesn't need labeled test data:
  if the uncertainty for the test data does not 
  decrease for a certain amount of iterations the training stops
  '''
  #val = val_accuracy[max_index]

 
  mean_entropy = np.mean((list_entropys3(model_entro, val_padded)))

  
  wait += 1
  if mean_entropy < best:
    best = mean_entropy
    wait = 0
  if wait >= patience:
    break

  
  print(f"Mean entropy for test data: {mean_entropy} - Lowest entropy for test data: {best}")


'''
visualize training
'''
test = plt.figure()
plt.plot(train_accuracies)
plt.plot(val_accuracies)
plt.ylabel('accuracy')
plt.xlabel('Iteration')
plt.legend(['train', 'val'], loc='upper left')

result = np.round(np.amax(val_accuracies), decimals = 4)
plt.title(f'model accuracy:{result}' )
plt.show()
# Out:
# Iteration :1 - Samples: 2048
#
# Epoch 1/30
# 32/32 [==============================] - 13s 213ms/step - loss: 4.5899 - accuracy: 0.4175 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 4.3783 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 32/32 [==============================] - 4s 127ms/step - loss: 4.1953 - accuracy: 0.4131 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.9978 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 32/32 [==============================] - 4s 132ms/step - loss: 3.8387 - accuracy: 0.4404 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.6575 - val_accuracy: 0.5026 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 32/32 [==============================] - 4s 115ms/step - loss: 3.5149 - accuracy: 0.4580 - precision: 1.0000 - recall: 4.8828e-04 - val_loss: 3.3479 - val_accuracy: 0.4968 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 32/32 [==============================] - 4s 132ms/step - loss: 3.2198 - accuracy: 0.4683 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.0666 - val_accuracy: 0.5090 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/30
# 32/32 [==============================] - 4s 135ms/step - loss: 2.9435 - accuracy: 0.5020 - precision: 0.7368 - recall: 0.0068 - val_loss: 2.8079 - val_accuracy: 0.5118 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/30
# 32/32 [==============================] - 5s 165ms/step - loss: 2.6927 - accuracy: 0.5142 - precision: 0.8621 - recall: 0.0244 - val_loss: 2.5713 - val_accuracy: 0.5234 - val_precision: 0.8615 - val_recall: 0.0147
# Epoch 8/30
# 32/32 [==============================] - 5s 165ms/step - loss: 2.4608 - accuracy: 0.5415 - precision: 0.8248 - recall: 0.0552 - val_loss: 2.3560 - val_accuracy: 0.5247 - val_precision: 0.7544 - val_recall: 0.0793
# Epoch 9/30
# 32/32 [==============================] - 4s 125ms/step - loss: 2.2434 - accuracy: 0.5654 - precision: 0.7817 - recall: 0.0962 - val_loss: 2.1586 - val_accuracy: 0.5134 - val_precision: 0.7373 - val_recall: 0.0879
# Epoch 10/30
# 32/32 [==============================] - 4s 125ms/step - loss: 2.0437 - accuracy: 0.5947 - precision: 0.7925 - recall: 0.1230 - val_loss: 1.9821 - val_accuracy: 0.5232 - val_precision: 0.7174 - val_recall: 0.0943
# Epoch 11/30
# 32/32 [==============================] - 5s 165ms/step - loss: 1.8599 - accuracy: 0.6084 - precision: 0.8249 - recall: 0.1748 - val_loss: 1.8229 - val_accuracy: 0.5345 - val_precision: 0.7274 - val_recall: 0.1145
# Epoch 12/30
# 32/32 [==============================] - 5s 166ms/step - loss: 1.6910 - accuracy: 0.6519 - precision: 0.8536 - recall: 0.2676 - val_loss: 1.6805 - val_accuracy: 0.5637 - val_precision: 0.7326 - val_recall: 0.1609
# Epoch 13/30
# 32/32 [==============================] - 5s 163ms/step - loss: 1.5175 - accuracy: 0.6953 - precision: 0.8620 - recall: 0.3721 - val_loss: 1.5514 - val_accuracy: 0.5877 - val_precision: 0.7285 - val_recall: 0.2472
# Epoch 14/30
# 32/32 [==============================] - 5s 167ms/step - loss: 1.3588 - accuracy: 0.7407 - precision: 0.8726 - recall: 0.5083 - val_loss: 1.4348 - val_accuracy: 0.6014 - val_precision: 0.7465 - val_recall: 0.3481
# Epoch 15/30
# 32/32 [==============================] - 5s 163ms/step - loss: 1.1937 - accuracy: 0.7876 - precision: 0.8697 - recall: 0.6162 - val_loss: 1.3308 - val_accuracy: 0.6251 - val_precision: 0.7257 - val_recall: 0.4508
# Epoch 16/30
# 32/32 [==============================] - 5s 167ms/step - loss: 1.0222 - accuracy: 0.8262 - precision: 0.8796 - recall: 0.7241 - val_loss: 1.2378 - val_accuracy: 0.6448 - val_precision: 0.7164 - val_recall: 0.5361
# Epoch 17/30
# 32/32 [==============================] - 5s 167ms/step - loss: 0.8510 - accuracy: 0.8579 - precision: 0.8874 - recall: 0.8081 - val_loss: 1.1948 - val_accuracy: 0.6509 - val_precision: 0.7044 - val_recall: 0.5798
# Epoch 18/30
# 32/32 [==============================] - 4s 127ms/step - loss: 0.7025 - accuracy: 0.8794 - precision: 0.9021 - recall: 0.8506 - val_loss: 1.1909 - val_accuracy: 0.6506 - val_precision: 0.6929 - val_recall: 0.6019
# Epoch 19/30
# 32/32 [==============================] - 5s 166ms/step - loss: 0.5903 - accuracy: 0.9087 - precision: 0.9209 - recall: 0.8872 - val_loss: 1.1672 - val_accuracy: 0.6561 - val_precision: 0.6882 - val_recall: 0.6074
# Epoch 20/30
# 32/32 [==============================] - 4s 128ms/step - loss: 0.5048 - accuracy: 0.9268 - precision: 0.9401 - recall: 0.9111 - val_loss: 1.2192 - val_accuracy: 0.6522 - val_precision: 0.6796 - val_recall: 0.6108
# Epoch 21/30
# 32/32 [==============================] - 5s 166ms/step - loss: 0.4475 - accuracy: 0.9424 - precision: 0.9501 - recall: 0.9297 - val_loss: 1.2021 - val_accuracy: 0.6596 - val_precision: 0.6792 - val_recall: 0.6193
# Epoch 22/30
# 32/32 [==============================] - 5s 165ms/step - loss: 0.3807 - accuracy: 0.9580 - precision: 0.9667 - recall: 0.9482 - val_loss: 1.1879 - val_accuracy: 0.6614 - val_precision: 0.6837 - val_recall: 0.6256
# Mean entropy for test data: 0.4959720657056289 - Lowest entropy for test data: 0.4959720657056289
#
# Iteration :2 - Samples: 4096
#
# Epoch 1/30
# 64/64 [==============================] - 6s 90ms/step - loss: 4.5183 - accuracy: 0.4077 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 4.1687 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 64/64 [==============================] - 4s 68ms/step - loss: 3.8873 - accuracy: 0.4106 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.5666 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 64/64 [==============================] - 4s 68ms/step - loss: 3.3360 - accuracy: 0.4072 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.0575 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 64/64 [==============================] - 4s 68ms/step - loss: 2.8683 - accuracy: 0.4102 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.6296 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 64/64 [==============================] - 4s 67ms/step - loss: 2.4797 - accuracy: 0.4148 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.2802 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/30
# 64/64 [==============================] - 4s 68ms/step - loss: 2.1613 - accuracy: 0.4170 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9952 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/30
# 64/64 [==============================] - 4s 67ms/step - loss: 1.9038 - accuracy: 0.4314 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.7667 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/30
# 64/64 [==============================] - 5s 76ms/step - loss: 1.6990 - accuracy: 0.4294 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.5900 - val_accuracy: 0.4308 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/30
# 64/64 [==============================] - 5s 77ms/step - loss: 1.5397 - accuracy: 0.4404 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4525 - val_accuracy: 0.4426 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/30
# 64/64 [==============================] - 5s 83ms/step - loss: 1.4085 - accuracy: 0.4641 - precision: 1.0000 - recall: 0.0034 - val_loss: 1.3415 - val_accuracy: 0.4487 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/30
# 64/64 [==============================] - 5s 75ms/step - loss: 1.2993 - accuracy: 0.4866 - precision: 0.8900 - recall: 0.0435 - val_loss: 1.2488 - val_accuracy: 0.4974 - val_precision: 0.8817 - val_recall: 0.0216
# Epoch 12/30
# 64/64 [==============================] - 6s 89ms/step - loss: 1.1973 - accuracy: 0.5759 - precision: 0.8660 - recall: 0.1025 - val_loss: 1.1679 - val_accuracy: 0.5516 - val_precision: 0.7421 - val_recall: 0.1182
# Epoch 13/30
# 64/64 [==============================] - 5s 75ms/step - loss: 1.0827 - accuracy: 0.6636 - precision: 0.8725 - recall: 0.2039 - val_loss: 1.0836 - val_accuracy: 0.5969 - val_precision: 0.7309 - val_recall: 0.1738
# Epoch 14/30
# 64/64 [==============================] - 5s 77ms/step - loss: 0.9542 - accuracy: 0.7368 - precision: 0.8878 - recall: 0.3477 - val_loss: 0.9956 - val_accuracy: 0.6440 - val_precision: 0.7771 - val_recall: 0.3194
# Epoch 15/30
# 64/64 [==============================] - 6s 102ms/step - loss: 0.8020 - accuracy: 0.8103 - precision: 0.9071 - recall: 0.5459 - val_loss: 0.9107 - val_accuracy: 0.6727 - val_precision: 0.7708 - val_recall: 0.4729
# Epoch 16/30
# 64/64 [==============================] - 5s 76ms/step - loss: 0.6366 - accuracy: 0.8630 - precision: 0.9194 - recall: 0.7324 - val_loss: 0.8529 - val_accuracy: 0.6967 - val_precision: 0.7609 - val_recall: 0.5766
# Epoch 17/30
# 64/64 [==============================] - 5s 85ms/step - loss: 0.4774 - accuracy: 0.9080 - precision: 0.9376 - recall: 0.8584 - val_loss: 0.8613 - val_accuracy: 0.7096 - val_precision: 0.7454 - val_recall: 0.6506
# Epoch 18/30
# 64/64 [==============================] - 4s 67ms/step - loss: 0.3611 - accuracy: 0.9414 - precision: 0.9540 - recall: 0.9170 - val_loss: 0.9270 - val_accuracy: 0.7027 - val_precision: 0.7288 - val_recall: 0.6667
# Epoch 19/30
# 64/64 [==============================] - 4s 68ms/step - loss: 0.2967 - accuracy: 0.9578 - precision: 0.9670 - recall: 0.9434 - val_loss: 0.9599 - val_accuracy: 0.6991 - val_precision: 0.7195 - val_recall: 0.6732
# Mean entropy for test data: 0.6082662460257535 - Lowest entropy for test data: 0.4959720657056289
#
# Iteration :3 - Samples: 6144
#
# Epoch 1/30
# 96/96 [==============================] - 7s 63ms/step - loss: 4.3571 - accuracy: 0.3753 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.8404 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 96/96 [==============================] - 5s 55ms/step - loss: 3.4417 - accuracy: 0.3765 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.0176 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 96/96 [==============================] - 5s 54ms/step - loss: 2.7220 - accuracy: 0.3768 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.3937 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 96/96 [==============================] - 6s 60ms/step - loss: 2.1834 - accuracy: 0.3805 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9368 - val_accuracy: 0.4323 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 96/96 [==============================] - 6s 60ms/step - loss: 1.7986 - accuracy: 0.3919 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6151 - val_accuracy: 0.4331 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/30
# 96/96 [==============================] - 6s 59ms/step - loss: 1.5341 - accuracy: 0.3986 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3984 - val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/30
# 96/96 [==============================] - 6s 59ms/step - loss: 1.3562 - accuracy: 0.4141 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2582 - val_accuracy: 0.4579 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/30
# 96/96 [==============================] - 6s 61ms/step - loss: 1.2349 - accuracy: 0.4606 - precision: 0.8571 - recall: 0.0039 - val_loss: 1.1568 - val_accuracy: 0.4660 - val_precision: 0.9524 - val_recall: 0.0105
# Epoch 9/30
# 96/96 [==============================] - 6s 60ms/step - loss: 1.1455 - accuracy: 0.5093 - precision: 0.7821 - recall: 0.0298 - val_loss: 1.0848 - val_accuracy: 0.5129 - val_precision: 0.7403 - val_recall: 0.0856
# Epoch 10/30
# 96/96 [==============================] - 6s 59ms/step - loss: 1.0569 - accuracy: 0.6112 - precision: 0.7861 - recall: 0.0789 - val_loss: 1.0124 - val_accuracy: 0.5727 - val_precision: 0.6890 - val_recall: 0.1540
# Epoch 11/30
# 96/96 [==============================] - 6s 61ms/step - loss: 0.9398 - accuracy: 0.6921 - precision: 0.8410 - recall: 0.2126 - val_loss: 0.9185 - val_accuracy: 0.6398 - val_precision: 0.7511 - val_recall: 0.2630
# Epoch 12/30
# 96/96 [==============================] - 6s 59ms/step - loss: 0.7708 - accuracy: 0.7868 - precision: 0.8899 - recall: 0.4829 - val_loss: 0.8198 - val_accuracy: 0.6869 - val_precision: 0.7677 - val_recall: 0.4968
# Epoch 13/30
# 96/96 [==============================] - 6s 60ms/step - loss: 0.5836 - accuracy: 0.8507 - precision: 0.9045 - recall: 0.7399 - val_loss: 0.7236 - val_accuracy: 0.7278 - val_precision: 0.7740 - val_recall: 0.6403
# Epoch 14/30
# 96/96 [==============================] - 6s 60ms/step - loss: 0.4324 - accuracy: 0.8973 - precision: 0.9215 - recall: 0.8540 - val_loss: 0.6914 - val_accuracy: 0.7446 - val_precision: 0.7783 - val_recall: 0.6996
# Epoch 15/30
# 96/96 [==============================] - 6s 60ms/step - loss: 0.3241 - accuracy: 0.9305 - precision: 0.9438 - recall: 0.9076 - val_loss: 0.6962 - val_accuracy: 0.7486 - val_precision: 0.7706 - val_recall: 0.7191
# Epoch 16/30
# 96/96 [==============================] - 6s 60ms/step - loss: 0.2506 - accuracy: 0.9508 - precision: 0.9583 - recall: 0.9417 - val_loss: 0.7286 - val_accuracy: 0.7525 - val_precision: 0.7695 - val_recall: 0.7349
# Epoch 17/30
# 96/96 [==============================] - 6s 59ms/step - loss: 0.2012 - accuracy: 0.9626 - precision: 0.9681 - recall: 0.9575 - val_loss: 0.7572 - val_accuracy: 0.7601 - val_precision: 0.7713 - val_recall: 0.7433
# Mean entropy for test data: 0.3832983472465571 - Lowest entropy for test data: 0.3832983472465571
#
# Iteration :4 - Samples: 8192
#
# Epoch 1/30
# 128/128 [==============================] - 8s 55ms/step - loss: 4.1977 - accuracy: 0.3561 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.5492 - val_accuracy: 0.4300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 128/128 [==============================] - 7s 52ms/step - loss: 3.0574 - accuracy: 0.3579 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.5841 - val_accuracy: 0.4331 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 128/128 [==============================] - 7s 51ms/step - loss: 2.2613 - accuracy: 0.3660 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9404 - val_accuracy: 0.4373 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 128/128 [==============================] - 7s 52ms/step - loss: 1.7499 - accuracy: 0.3798 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.5409 - val_accuracy: 0.4413 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 128/128 [==============================] - 7s 52ms/step - loss: 1.4451 - accuracy: 0.3905 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3092 - val_accuracy: 0.4466 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/30
# 128/128 [==============================] - 7s 54ms/step - loss: 1.2736 - accuracy: 0.4023 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.1863 - val_accuracy: 0.4595 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/30
# 128/128 [==============================] - 7s 53ms/step - loss: 1.1789 - accuracy: 0.4404 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.1180 - val_accuracy: 0.4792 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/30
# 128/128 [==============================] - 7s 52ms/step - loss: 1.1198 - accuracy: 0.4785 - precision: 0.7975 - recall: 0.0077 - val_loss: 1.0611 - val_accuracy: 0.4937 - val_precision: 0.7551 - val_recall: 0.0487
# Epoch 9/30
# 128/128 [==============================] - 7s 53ms/step - loss: 1.0723 - accuracy: 0.5239 - precision: 0.7131 - recall: 0.0325 - val_loss: 1.0164 - val_accuracy: 0.5521 - val_precision: 0.6909 - val_recall: 0.1101
# Epoch 10/30
# 128/128 [==============================] - 7s 53ms/step - loss: 1.0086 - accuracy: 0.5896 - precision: 0.7672 - recall: 0.0938 - val_loss: 0.9663 - val_accuracy: 0.5653 - val_precision: 0.6900 - val_recall: 0.1846
# Epoch 11/30
# 128/128 [==============================] - 7s 52ms/step - loss: 0.9009 - accuracy: 0.6697 - precision: 0.8366 - recall: 0.2570 - val_loss: 0.8821 - val_accuracy: 0.6245 - val_precision: 0.7162 - val_recall: 0.2996
# Epoch 12/30
# 128/128 [==============================] - 7s 52ms/step - loss: 0.7304 - accuracy: 0.7683 - precision: 0.8715 - recall: 0.5181 - val_loss: 0.7859 - val_accuracy: 0.6840 - val_precision: 0.7482 - val_recall: 0.5374
# Epoch 13/30
# 128/128 [==============================] - 7s 51ms/step - loss: 0.5410 - accuracy: 0.8512 - precision: 0.9006 - recall: 0.7566 - val_loss: 0.7010 - val_accuracy: 0.7317 - val_precision: 0.7641 - val_recall: 0.6730
# Epoch 14/30
# 128/128 [==============================] - 7s 52ms/step - loss: 0.3889 - accuracy: 0.8983 - precision: 0.9192 - recall: 0.8651 - val_loss: 0.6642 - val_accuracy: 0.7562 - val_precision: 0.7710 - val_recall: 0.7270
# Epoch 15/30
# 128/128 [==============================] - 7s 52ms/step - loss: 0.2837 - accuracy: 0.9303 - precision: 0.9430 - recall: 0.9147 - val_loss: 0.6646 - val_accuracy: 0.7659 - val_precision: 0.7779 - val_recall: 0.7514
# Epoch 16/30
# 128/128 [==============================] - 7s 52ms/step - loss: 0.2175 - accuracy: 0.9495 - precision: 0.9565 - recall: 0.9404 - val_loss: 0.6834 - val_accuracy: 0.7717 - val_precision: 0.7823 - val_recall: 0.7599
# Epoch 17/30
# 128/128 [==============================] - 7s 51ms/step - loss: 0.1695 - accuracy: 0.9661 - precision: 0.9689 - recall: 0.9622 - val_loss: 0.7246 - val_accuracy: 0.7765 - val_precision: 0.7830 - val_recall: 0.7659
# Mean entropy for test data: 0.34895083628870277 - Lowest entropy for test data: 0.34895083628870277
#
# Iteration :5 - Samples: 10240
#
# Epoch 1/30
# 160/160 [==============================] - 9s 49ms/step - loss: 4.0365 - accuracy: 0.3622 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.2622 - val_accuracy: 0.4308 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 160/160 [==============================] - 8s 47ms/step - loss: 2.7100 - accuracy: 0.3661 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.2023 - val_accuracy: 0.4331 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 160/160 [==============================] - 7s 47ms/step - loss: 1.8960 - accuracy: 0.3700 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6015 - val_accuracy: 0.4431 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 160/160 [==============================] - 7s 44ms/step - loss: 1.4549 - accuracy: 0.3788 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2855 - val_accuracy: 0.4413 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 160/160 [==============================] - 8s 47ms/step - loss: 1.2423 - accuracy: 0.3913 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.1468 - val_accuracy: 0.4516 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/30
# 160/160 [==============================] - 8s 47ms/step - loss: 1.1453 - accuracy: 0.4028 - precision: 0.7500 - recall: 5.8594e-04 - val_loss: 1.0810 - val_accuracy: 0.4658 - val_precision: 1.0000 - val_recall: 2.6330e-04
# Epoch 7/30
# 160/160 [==============================] - 8s 47ms/step - loss: 1.0966 - accuracy: 0.4352 - precision: 0.7302 - recall: 0.0135 - val_loss: 1.0356 - val_accuracy: 0.4668 - val_precision: 0.7176 - val_recall: 0.0742
# Epoch 8/30
# 160/160 [==============================] - 8s 47ms/step - loss: 1.0628 - accuracy: 0.4811 - precision: 0.6696 - recall: 0.0370 - val_loss: 1.0034 - val_accuracy: 0.4900 - val_precision: 0.6680 - val_recall: 0.1309
# Epoch 9/30
# 160/160 [==============================] - 8s 48ms/step - loss: 1.0179 - accuracy: 0.5379 - precision: 0.7245 - recall: 0.0686 - val_loss: 0.9583 - val_accuracy: 0.5585 - val_precision: 0.6977 - val_recall: 0.1380
# Epoch 10/30
# 160/160 [==============================] - 8s 47ms/step - loss: 0.9403 - accuracy: 0.6138 - precision: 0.8108 - recall: 0.1782 - val_loss: 0.8969 - val_accuracy: 0.6116 - val_precision: 0.7338 - val_recall: 0.2475
# Epoch 11/30
# 160/160 [==============================] - 8s 47ms/step - loss: 0.7987 - accuracy: 0.7146 - precision: 0.8407 - recall: 0.4057 - val_loss: 0.7924 - val_accuracy: 0.6788 - val_precision: 0.7523 - val_recall: 0.4837
# Epoch 12/30
# 160/160 [==============================] - 7s 47ms/step - loss: 0.6079 - accuracy: 0.8111 - precision: 0.8778 - recall: 0.6698 - val_loss: 0.6910 - val_accuracy: 0.7383 - val_precision: 0.7731 - val_recall: 0.6701
# Epoch 13/30
# 160/160 [==============================] - 8s 48ms/step - loss: 0.4349 - accuracy: 0.8814 - precision: 0.9078 - recall: 0.8331 - val_loss: 0.6392 - val_accuracy: 0.7643 - val_precision: 0.7858 - val_recall: 0.7380
# Epoch 14/30
# 160/160 [==============================] - 8s 47ms/step - loss: 0.3131 - accuracy: 0.9215 - precision: 0.9348 - recall: 0.9009 - val_loss: 0.6414 - val_accuracy: 0.7754 - val_precision: 0.7882 - val_recall: 0.7615
# Epoch 15/30
# 160/160 [==============================] - 8s 48ms/step - loss: 0.2351 - accuracy: 0.9439 - precision: 0.9515 - recall: 0.9349 - val_loss: 0.6659 - val_accuracy: 0.7875 - val_precision: 0.7948 - val_recall: 0.7783
# Epoch 16/30
# 160/160 [==============================] - 7s 44ms/step - loss: 0.1854 - accuracy: 0.9614 - precision: 0.9665 - recall: 0.9543 - val_loss: 0.7044 - val_accuracy: 0.7867 - val_precision: 0.7941 - val_recall: 0.7791
# Mean entropy for test data: 0.3843940728295084 - Lowest entropy for test data: 0.34895083628870277
#
# Iteration :6 - Samples: 12288
#
# Epoch 1/30
# 192/192 [==============================] - 10s 46ms/step - loss: 3.8892 - accuracy: 0.3559 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.0114 - val_accuracy: 0.4505 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 192/192 [==============================] - 9s 45ms/step - loss: 2.4262 - accuracy: 0.3702 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9240 - val_accuracy: 0.4529 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 192/192 [==============================] - 8s 44ms/step - loss: 1.6453 - accuracy: 0.3804 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3947 - val_accuracy: 0.4544 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 192/192 [==============================] - 9s 44ms/step - loss: 1.2950 - accuracy: 0.3940 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.1762 - val_accuracy: 0.4692 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 192/192 [==============================] - 8s 42ms/step - loss: 1.1579 - accuracy: 0.4094 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0895 - val_accuracy: 0.4674 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/30
# 192/192 [==============================] - 9s 46ms/step - loss: 1.1013 - accuracy: 0.4439 - precision: 0.6739 - recall: 0.0076 - val_loss: 1.0406 - val_accuracy: 0.4897 - val_precision: 0.7273 - val_recall: 0.0463
# Epoch 7/30
# 192/192 [==============================] - 8s 44ms/step - loss: 1.0657 - accuracy: 0.4771 - precision: 0.6359 - recall: 0.0314 - val_loss: 1.0036 - val_accuracy: 0.5011 - val_precision: 0.6463 - val_recall: 0.1395
# Epoch 8/30
# 192/192 [==============================] - 8s 44ms/step - loss: 1.0190 - accuracy: 0.5301 - precision: 0.7086 - recall: 0.0863 - val_loss: 0.9592 - val_accuracy: 0.5242 - val_precision: 0.6717 - val_recall: 0.1972
# Epoch 9/30
# 192/192 [==============================] - 8s 44ms/step - loss: 0.9269 - accuracy: 0.6048 - precision: 0.7779 - recall: 0.2263 - val_loss: 0.8792 - val_accuracy: 0.5943 - val_precision: 0.6795 - val_recall: 0.3210
# Epoch 10/30
# 192/192 [==============================] - 8s 44ms/step - loss: 0.7741 - accuracy: 0.7054 - precision: 0.8114 - recall: 0.4516 - val_loss: 0.7849 - val_accuracy: 0.6722 - val_precision: 0.7242 - val_recall: 0.5074
# Epoch 11/30
# 192/192 [==============================] - 9s 44ms/step - loss: 0.6012 - accuracy: 0.7975 - precision: 0.8556 - recall: 0.6852 - val_loss: 0.7001 - val_accuracy: 0.7262 - val_precision: 0.7546 - val_recall: 0.6746
# Epoch 12/30
# 192/192 [==============================] - 9s 44ms/step - loss: 0.4405 - accuracy: 0.8704 - precision: 0.8943 - recall: 0.8279 - val_loss: 0.6398 - val_accuracy: 0.7686 - val_precision: 0.7842 - val_recall: 0.7462
# Epoch 13/30
# 192/192 [==============================] - 8s 44ms/step - loss: 0.3195 - accuracy: 0.9130 - precision: 0.9245 - recall: 0.8943 - val_loss: 0.6222 - val_accuracy: 0.7862 - val_precision: 0.7976 - val_recall: 0.7730
# Epoch 14/30
# 192/192 [==============================] - 9s 44ms/step - loss: 0.2423 - accuracy: 0.9377 - precision: 0.9453 - recall: 0.9277 - val_loss: 0.6304 - val_accuracy: 0.7933 - val_precision: 0.8017 - val_recall: 0.7854
# Epoch 15/30
# 192/192 [==============================] - 8s 44ms/step - loss: 0.1946 - accuracy: 0.9510 - precision: 0.9558 - recall: 0.9458 - val_loss: 0.6572 - val_accuracy: 0.7936 - val_precision: 0.8008 - val_recall: 0.7862
# Epoch 16/30
# 192/192 [==============================] - 8s 41ms/step - loss: 0.1584 - accuracy: 0.9620 - precision: 0.9657 - recall: 0.9579 - val_loss: 0.6854 - val_accuracy: 0.7933 - val_precision: 0.8009 - val_recall: 0.7878
# Mean entropy for test data: 0.3479312661884825 - Lowest entropy for test data: 0.3479312661884825
#
# Iteration :7 - Samples: 14336
#
# Epoch 1/30
# 224/224 [==============================] - 10s 43ms/step - loss: 3.7515 - accuracy: 0.3578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.7739 - val_accuracy: 0.4342 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 224/224 [==============================] - 9s 42ms/step - loss: 2.1909 - accuracy: 0.3707 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6879 - val_accuracy: 0.4444 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 224/224 [==============================] - 9s 42ms/step - loss: 1.4695 - accuracy: 0.3867 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2477 - val_accuracy: 0.4526 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 224/224 [==============================] - 9s 42ms/step - loss: 1.2012 - accuracy: 0.4018 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0976 - val_accuracy: 0.4739 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 224/224 [==============================] - 9s 42ms/step - loss: 1.1116 - accuracy: 0.4288 - precision: 0.7130 - recall: 0.0054 - val_loss: 1.0365 - val_accuracy: 0.4879 - val_precision: 0.7371 - val_recall: 0.0413
# Epoch 6/30
# 224/224 [==============================] - 9s 42ms/step - loss: 1.0700 - accuracy: 0.4604 - precision: 0.6418 - recall: 0.0300 - val_loss: 1.0008 - val_accuracy: 0.5068 - val_precision: 0.6865 - val_recall: 0.1095
# Epoch 7/30
# 224/224 [==============================] - 9s 42ms/step - loss: 1.0244 - accuracy: 0.5033 - precision: 0.6803 - recall: 0.0729 - val_loss: 0.9485 - val_accuracy: 0.5229 - val_precision: 0.6788 - val_recall: 0.1859
# Epoch 8/30
# 224/224 [==============================] - 9s 42ms/step - loss: 0.9478 - accuracy: 0.5785 - precision: 0.7444 - recall: 0.1835 - val_loss: 0.8818 - val_accuracy: 0.5924 - val_precision: 0.6888 - val_recall: 0.2791
# Epoch 9/30
# 224/224 [==============================] - 9s 42ms/step - loss: 0.8243 - accuracy: 0.6664 - precision: 0.7892 - recall: 0.3786 - val_loss: 0.7950 - val_accuracy: 0.6688 - val_precision: 0.7245 - val_recall: 0.4758
# Epoch 10/30
# 224/224 [==============================] - 9s 42ms/step - loss: 0.6703 - accuracy: 0.7569 - precision: 0.8264 - recall: 0.6087 - val_loss: 0.7014 - val_accuracy: 0.7351 - val_precision: 0.7712 - val_recall: 0.6619
# Epoch 11/30
# 224/224 [==============================] - 9s 42ms/step - loss: 0.5185 - accuracy: 0.8354 - precision: 0.8687 - recall: 0.7729 - val_loss: 0.6371 - val_accuracy: 0.7749 - val_precision: 0.7961 - val_recall: 0.7464
# Epoch 12/30
# 224/224 [==============================] - 9s 42ms/step - loss: 0.3844 - accuracy: 0.8896 - precision: 0.9066 - recall: 0.8636 - val_loss: 0.6158 - val_accuracy: 0.7875 - val_precision: 0.8028 - val_recall: 0.7717
# Epoch 13/30
# 224/224 [==============================] - 9s 42ms/step - loss: 0.2969 - accuracy: 0.9192 - precision: 0.9303 - recall: 0.9083 - val_loss: 0.6250 - val_accuracy: 0.7954 - val_precision: 0.8085 - val_recall: 0.7849
# Epoch 14/30
# 224/224 [==============================] - 9s 42ms/step - loss: 0.2349 - accuracy: 0.9402 - precision: 0.9469 - recall: 0.9320 - val_loss: 0.6548 - val_accuracy: 0.7965 - val_precision: 0.8039 - val_recall: 0.7867
# Epoch 15/30
# 224/224 [==============================] - 9s 40ms/step - loss: 0.1916 - accuracy: 0.9537 - precision: 0.9599 - recall: 0.9492 - val_loss: 0.6920 - val_accuracy: 0.7938 - val_precision: 0.7987 - val_recall: 0.7825
# Mean entropy for test data: 0.35079571815672417 - Lowest entropy for test data: 0.3479312661884825
#
# Iteration :8 - Samples: 16384
#
# Epoch 1/30
# 256/256 [==============================] - 11s 41ms/step - loss: 3.6262 - accuracy: 0.3593 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.5750 - val_accuracy: 0.4447 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 256/256 [==============================] - 10s 38ms/step - loss: 2.0046 - accuracy: 0.3677 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.5309 - val_accuracy: 0.4439 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 256/256 [==============================] - 10s 40ms/step - loss: 1.3582 - accuracy: 0.3909 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.1727 - val_accuracy: 0.4542 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 256/256 [==============================] - 10s 41ms/step - loss: 1.1580 - accuracy: 0.4068 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0759 - val_accuracy: 0.4813 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 256/256 [==============================] - 10s 40ms/step - loss: 1.0947 - accuracy: 0.4352 - precision: 0.6557 - recall: 0.0024 - val_loss: 1.0217 - val_accuracy: 0.5263 - val_precision: 0.8118 - val_recall: 0.0182
# Epoch 6/30
# 256/256 [==============================] - 10s 40ms/step - loss: 1.0532 - accuracy: 0.4742 - precision: 0.6650 - recall: 0.0327 - val_loss: 0.9750 - val_accuracy: 0.5595 - val_precision: 0.7398 - val_recall: 0.1093
# Epoch 7/30
# 256/256 [==============================] - 10s 40ms/step - loss: 0.9955 - accuracy: 0.5292 - precision: 0.7081 - recall: 0.1094 - val_loss: 0.9060 - val_accuracy: 0.6101 - val_precision: 0.7535 - val_recall: 0.1956
# Epoch 8/30
# 256/256 [==============================] - 10s 41ms/step - loss: 0.8969 - accuracy: 0.6184 - precision: 0.7596 - recall: 0.2734 - val_loss: 0.7998 - val_accuracy: 0.6856 - val_precision: 0.7832 - val_recall: 0.4518
# Epoch 9/30
# 256/256 [==============================] - 10s 41ms/step - loss: 0.7375 - accuracy: 0.7338 - precision: 0.8089 - recall: 0.5436 - val_loss: 0.6726 - val_accuracy: 0.7549 - val_precision: 0.7942 - val_recall: 0.6625
# Epoch 10/30
# 256/256 [==============================] - 10s 41ms/step - loss: 0.5620 - accuracy: 0.8201 - precision: 0.8535 - recall: 0.7456 - val_loss: 0.5803 - val_accuracy: 0.7888 - val_precision: 0.8099 - val_recall: 0.7549
# Epoch 11/30
# 256/256 [==============================] - 10s 40ms/step - loss: 0.4219 - accuracy: 0.8759 - precision: 0.8922 - recall: 0.8483 - val_loss: 0.5580 - val_accuracy: 0.8054 - val_precision: 0.8183 - val_recall: 0.7862
# Epoch 12/30
# 256/256 [==============================] - 10s 41ms/step - loss: 0.3168 - accuracy: 0.9159 - precision: 0.9259 - recall: 0.9048 - val_loss: 0.5783 - val_accuracy: 0.8110 - val_precision: 0.8188 - val_recall: 0.7986
# Epoch 13/30
# 256/256 [==============================] - 10s 40ms/step - loss: 0.2461 - accuracy: 0.9386 - precision: 0.9452 - recall: 0.9310 - val_loss: 0.6157 - val_accuracy: 0.8133 - val_precision: 0.8201 - val_recall: 0.8031
# Epoch 14/30
# 256/256 [==============================] - 10s 39ms/step - loss: 0.1990 - accuracy: 0.9534 - precision: 0.9602 - recall: 0.9479 - val_loss: 0.6571 - val_accuracy: 0.8031 - val_precision: 0.8113 - val_recall: 0.7967
# Mean entropy for test data: 0.30838340887595445 - Lowest entropy for test data: 0.30838340887595445
#
# Iteration :9 - Samples: 18432
#
# Epoch 1/30
# 288/288 [==============================] - 12s 40ms/step - loss: 3.5098 - accuracy: 0.3621 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.3985 - val_accuracy: 0.4352 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 288/288 [==============================] - 11s 39ms/step - loss: 1.8521 - accuracy: 0.3745 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4098 - val_accuracy: 0.4384 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 288/288 [==============================] - 11s 39ms/step - loss: 1.2847 - accuracy: 0.3899 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.1294 - val_accuracy: 0.4737 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 288/288 [==============================] - 11s 39ms/step - loss: 1.1326 - accuracy: 0.4102 - precision: 0.5484 - recall: 0.0018 - val_loss: 1.0470 - val_accuracy: 0.5153 - val_precision: 0.7500 - val_recall: 7.8989e-04
# Epoch 5/30
# 288/288 [==============================] - 11s 39ms/step - loss: 1.0762 - accuracy: 0.4439 - precision: 0.6353 - recall: 0.0234 - val_loss: 0.9967 - val_accuracy: 0.5169 - val_precision: 0.7089 - val_recall: 0.1135
# Epoch 6/30
# 288/288 [==============================] - 11s 39ms/step - loss: 1.0211 - accuracy: 0.4957 - precision: 0.6633 - recall: 0.0846 - val_loss: 0.9363 - val_accuracy: 0.5613 - val_precision: 0.7222 - val_recall: 0.1964
# Epoch 7/30
# 288/288 [==============================] - 11s 39ms/step - loss: 0.9338 - accuracy: 0.5739 - precision: 0.7131 - recall: 0.2293 - val_loss: 0.8539 - val_accuracy: 0.6316 - val_precision: 0.7297 - val_recall: 0.3433
# Epoch 8/30
# 288/288 [==============================] - 11s 39ms/step - loss: 0.8116 - accuracy: 0.6639 - precision: 0.7601 - recall: 0.4314 - val_loss: 0.7624 - val_accuracy: 0.6859 - val_precision: 0.7457 - val_recall: 0.5358
# Epoch 9/30
# 288/288 [==============================] - 11s 39ms/step - loss: 0.6815 - accuracy: 0.7453 - precision: 0.7971 - recall: 0.6258 - val_loss: 0.6731 - val_accuracy: 0.7525 - val_precision: 0.7891 - val_recall: 0.6975
# Epoch 10/30
# 288/288 [==============================] - 11s 39ms/step - loss: 0.5479 - accuracy: 0.8176 - precision: 0.8436 - recall: 0.7625 - val_loss: 0.6000 - val_accuracy: 0.7912 - val_precision: 0.8110 - val_recall: 0.7662
# Epoch 11/30
# 288/288 [==============================] - 11s 39ms/step - loss: 0.4293 - accuracy: 0.8729 - precision: 0.8879 - recall: 0.8465 - val_loss: 0.5692 - val_accuracy: 0.8052 - val_precision: 0.8179 - val_recall: 0.7923
# Epoch 12/30
# 288/288 [==============================] - 11s 40ms/step - loss: 0.3332 - accuracy: 0.9084 - precision: 0.9180 - recall: 0.8963 - val_loss: 0.5802 - val_accuracy: 0.8123 - val_precision: 0.8225 - val_recall: 0.8017
# Epoch 13/30
# 288/288 [==============================] - 11s 38ms/step - loss: 0.2645 - accuracy: 0.9309 - precision: 0.9388 - recall: 0.9237 - val_loss: 0.6113 - val_accuracy: 0.8120 - val_precision: 0.8195 - val_recall: 0.8044
# Epoch 14/30
# 288/288 [==============================] - 11s 38ms/step - loss: 0.2175 - accuracy: 0.9478 - precision: 0.9535 - recall: 0.9412 - val_loss: 0.6596 - val_accuracy: 0.8112 - val_precision: 0.8189 - val_recall: 0.8046
# Mean entropy for test data: 0.38314093817435024 - Lowest entropy for test data: 0.30838340887595445
#
# Iteration :10 - Samples: 20480
#
# Epoch 1/30
# 320/320 [==============================] - 14s 40ms/step - loss: 3.3876 - accuracy: 0.3750 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.2158 - val_accuracy: 0.4071 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 320/320 [==============================] - 13s 39ms/step - loss: 1.6996 - accuracy: 0.3890 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2957 - val_accuracy: 0.4168 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 320/320 [==============================] - 12s 39ms/step - loss: 1.2045 - accuracy: 0.4081 - precision: 0.7857 - recall: 0.0011 - val_loss: 1.0758 - val_accuracy: 0.4889 - val_precision: 1.0000 - val_recall: 7.8989e-04
# Epoch 4/30
# 320/320 [==============================] - 12s 39ms/step - loss: 1.0853 - accuracy: 0.4285 - precision: 0.6181 - recall: 0.0126 - val_loss: 0.9985 - val_accuracy: 0.5121 - val_precision: 0.8636 - val_recall: 0.0100
# Epoch 5/30
# 320/320 [==============================] - 12s 39ms/step - loss: 1.0257 - accuracy: 0.4713 - precision: 0.6739 - recall: 0.0604 - val_loss: 0.9400 - val_accuracy: 0.5519 - val_precision: 0.7792 - val_recall: 0.1245
# Epoch 6/30
# 320/320 [==============================] - 13s 39ms/step - loss: 0.9445 - accuracy: 0.5431 - precision: 0.7000 - recall: 0.1889 - val_loss: 0.8578 - val_accuracy: 0.6148 - val_precision: 0.7539 - val_recall: 0.3057
# Epoch 7/30
# 320/320 [==============================] - 13s 39ms/step - loss: 0.8249 - accuracy: 0.6341 - precision: 0.7307 - recall: 0.3997 - val_loss: 0.7612 - val_accuracy: 0.6996 - val_precision: 0.7708 - val_recall: 0.5276
# Epoch 8/30
# 320/320 [==============================] - 13s 39ms/step - loss: 0.6968 - accuracy: 0.7230 - precision: 0.7766 - recall: 0.6019 - val_loss: 0.6609 - val_accuracy: 0.7546 - val_precision: 0.7906 - val_recall: 0.6859
# Epoch 9/30
# 320/320 [==============================] - 12s 39ms/step - loss: 0.5661 - accuracy: 0.8021 - precision: 0.8261 - recall: 0.7504 - val_loss: 0.5601 - val_accuracy: 0.7930 - val_precision: 0.8106 - val_recall: 0.7620
# Epoch 10/30
# 320/320 [==============================] - 13s 39ms/step - loss: 0.4470 - accuracy: 0.8553 - precision: 0.8690 - recall: 0.8326 - val_loss: 0.5134 - val_accuracy: 0.8075 - val_precision: 0.8229 - val_recall: 0.7925
# Epoch 11/30
# 320/320 [==============================] - 12s 39ms/step - loss: 0.3532 - accuracy: 0.8976 - precision: 0.9077 - recall: 0.8840 - val_loss: 0.5105 - val_accuracy: 0.8194 - val_precision: 0.8285 - val_recall: 0.8088
# Epoch 12/30
# 320/320 [==============================] - 13s 39ms/step - loss: 0.2775 - accuracy: 0.9252 - precision: 0.9338 - recall: 0.9175 - val_loss: 0.5311 - val_accuracy: 0.8241 - val_precision: 0.8326 - val_recall: 0.8133
# Epoch 13/30
# 320/320 [==============================] - 13s 39ms/step - loss: 0.2245 - accuracy: 0.9433 - precision: 0.9508 - recall: 0.9373 - val_loss: 0.5616 - val_accuracy: 0.8275 - val_precision: 0.8336 - val_recall: 0.8189
# Epoch 14/30
# 320/320 [==============================] - 12s 38ms/step - loss: 0.1867 - accuracy: 0.9551 - precision: 0.9614 - recall: 0.9495 - val_loss: 0.6040 - val_accuracy: 0.8273 - val_precision: 0.8330 - val_recall: 0.8183
# Mean entropy for test data: 0.2900293411400298 - Lowest entropy for test data: 0.2900293411400298

# %%
from numpy import asarray
from numpy import savetxt
from google.colab import files
'''
Saving the learning curve in csv file for later analyses.
'''

savetxt('val_accuracies.csv', np.round(val_accuracies, decimals= 4) , delimiter=',')

savetxt('train_accuracies.csv', np.round(train_accuracies, decimals= 4) , delimiter=',')

files.download('train_accuracies.csv')
files.download('val_accuracies.csv')

print(val_accuracies)
# Out:
# [0.6614007353782654, 0.7095839977264404, 0.7601369023323059, 0.7764613032341003, 0.7875197529792786, 0.7935755848884583, 0.7964718341827393, 0.8133227825164795, 0.8122696280479431, 0.8275408148765564]

# %% [markdown]
# # Visualize Embeddings

# %%
#transform data to matrices of word embeddings 
text2vector = vectorize(val_padded, model_entro)

# %%
from sklearn.manifold import TSNE
import seaborn as sns
#represent text as the mean embedding
np_vectorrep = np.array(text2vector)

np_vectorrep = np.mean(np_vectorrep, axis = 1)


item_tsne = TSNE(perplexity=30).fit_transform(np_vectorrep)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#displays the result of t-SNE
dic = {1: 'neutral',0: 'negative',2:'positive' }
sns.set_style("darkgrid")
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.scatterplot(data=item_tsne, x=item_tsne[:,0], y = item_tsne[:,1], hue = [dic[key] for key in val_labels_np])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:882: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   val in data
